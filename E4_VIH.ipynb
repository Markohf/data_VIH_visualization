# %% [markdown]
# <a href="https://colab.research.google.com/github/Markohf/data_VIH_visualization/blob/main/E4_VIH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import plotly.express as px

# %%
url='https://raw.githubusercontent.com/Markohf/data_VIH_visualization/main/Jan%202021%20Data%20-%20Viz5%20Gender%20Inequality%20and%20HIVAIDS.csv'
df=pd.read_csv(url, encoding = 'unicode_escape', engine ='python')

# %%
df.head(3)
# Out:
#   Country                UNICEF Region  Year     Sex        Age  \
# 0  Angola  Eastern and Southern Africa  1990  Female  Age 10-19
# 1  Angola  Eastern and Southern Africa  1990    Male  Age 10-19
# 2  Angola  Eastern and Southern Africa  1991  Female  Age 10-19
#
#    Estimated incidence rate of new HIV infection per 1 000 uninfected population   \
# 0                                               0.64
# 1                                               0.15
# 2                                               0.75
#
#    Estimated number of annual AIDS related deaths  \
# 0                                           100.0
# 1                                           100.0
# 2                                           100.0
#
#    Estimated number of annual new HIV infections  \
# 0                                          500.0
# 1                                          100.0
# 2                                          500.0
#
#    Estimated number of people living with HIV  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2640 entries, 0 to 2639
# Data columns (total 10 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Country                                                                         2640 non-null   object
#  1   UNICEF Region                                                                   2640 non-null   object
#  2   Year                                                                            2640 non-null   int64
#  3   Sex                                                                             2640 non-null   object
#  4   Age                                                                             2640 non-null   object
#  5   Estimated incidence rate of new HIV infection per 1 000 uninfected population   2520 non-null   float64
# ...

# %%
df.describe()
# Out:
#               Year  \
# count  2640.000000
# mean   2004.500000
# std       8.657081
# min    1990.000000
# 25%    1997.000000
# 50%    2004.500000
# 75%    2012.000000
# max    2019.000000
#
#        Estimated incidence rate of new HIV infection per 1 000 uninfected population   \
# count                                        2520.000000
# mean                                            3.751397
# std                                             7.660533
# min                                             0.010000
# 25%                                             0.320000
# 50%                                             1.150000
# 75%                                             3.500000
# max                                            70.630000
#
#        Estimated number of annual AIDS related deaths  \
# count                                     2580.000000
# mean                                       391.949612
# std                                        517.781115
# ...

# %%
fil1 = df['Year'] == 2019
df_2019 = df.loc[fil1]
df_2019.head()
# Out:
#      Country                UNICEF Region  Year     Sex        Age  \
# 58    Angola  Eastern and Southern Africa  2019  Female  Age 10-19
# 59    Angola  Eastern and Southern Africa  2019    Male  Age 10-19
# 118  Burundi  Eastern and Southern Africa  2019  Female  Age 10-19
# 119  Burundi  Eastern and Southern Africa  2019    Male  Age 10-19
# 178    Benin      West and Central Africa  2019  Female  Age 10-19
#
#      Estimated incidence rate of new HIV infection per 1 000 uninfected population   \
# 58                                                1.99
# 59                                                0.42
# 118                                               0.20
# 119                                               0.03
# 178                                               0.44
#
#      Estimated number of annual AIDS related deaths  \
# 58                                            500.0
# 59                                            500.0
# ...

# %%
px.box(df_2019, x="Sex", y="Estimated number of people living with HIV",width=900,height =500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
